# %% [markdown]
# ># <center>LAB 2 - Tokenization
#
# ---------------------------
#
# Name: **KRISH GOYAL** <br>
# Reg No: **21112015** <br>
# Class: **5 BSC DS** <br>

# %% [markdown]
# >_[Github Link](https://github.com/Krishnaa-tech/NLP.git)_

# %%
import spacy
from collections import Counter
import matplotlib.pyplot as plt

# Load the English NLP model from spaCy
nlp = spacy.load('en_core_web_sm')

# Read text from a file or you can replace this with your own text
with open('document.txt', 'r', encoding='utf-8') as file:
    text = file.read()

# Process the text with spaCy
doc = nlp(text)

# Initialize a Counter to count word frequencies
word_freq = Counter()

# Define a set of stop words from spaCy
stop_words = set(nlp.Defaults.stop_words)

# Iterate through each token in the spaCy document
for token in doc:
    clean_token = token.text.lower().strip()  # Convert to lowercase and strip whitespace

    # Check if the clean_token is alphanumeric and not a stop word
    if clean_token.isalpha() and clean_token not in stop_words:
        word_freq[clean_token] += 1

# Get the most common words and their frequencies
most_common_words = word_freq.most_common(10)  # Change the number to display more or fewer words

# Separate words and frequencies for plotting
words, frequencies = zip(*most_common_words)

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(words, frequencies)
plt.xlabel('Words')
plt.ylabel('Frequencies')
plt.title('Top Words by Frequency (Stop Words Removed)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()

# Show the plot
plt.show()

# Print word frequencies
print("Word Frequency:")
for word, freq in word_freq.items():
    print(f"{word}: {freq}")
# Out:
# Word Frequency:
# case: 1
# study: 1
# unlocking: 1
# growth: 1
# google: 50
# web: 36
# analytics: 56
# introduction: 1
# free: 1
# service: 2
# offered: 1
# allows: 5
# website: 7
# owners: 2
# track: 4
# analyse: 1
# traffic: 11
# provides: 3
# insights: 4
# behaviour: 2
# visitors: 2
# including: 2
# found: 1
# site: 5
# long: 1
# stayed: 1
# pages: 1
# viewed: 1
# actions: 1
# took: 1
# information: 2
# informed: 1
# decisions: 2
# optimising: 1
# websites: 6
# improving: 2
# performance: 17
# businesses: 3
# organisations: 1
# individuals: 1
# widely: 1
# use: 6
# measure: 2
# effectiveness: 2
# online: 3
# marketing: 4
# campaigns: 1
# improve: 2
# user: 9
# experience: 1
# increase: 2
# conversion: 4
# rates: 1
# helps: 1
# count: 1
# sources: 4
# goals: 1
# generates: 3
# reports: 1
# audience: 4
# analysis: 8
# acquisition: 3
# behavior: 5
# gives: 1
# overview: 1
# visit: 1
# session: 1
# history: 1
# technology: 4
# page: 2
# views: 3
# bounce: 1
# rate: 1
# carried: 1
# ...
