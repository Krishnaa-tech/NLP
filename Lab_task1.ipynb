# %% [markdown]
# # <center>LAB 0 - Text extraction
#
# ---------------------------
#
# Name: **KRISH GOYAL** <br>
# Reg No: **21112015** <br>
# Class: **5 BSC DS** <br>

# %% [markdown]
# [Github Link](https://github.com/Krishnaa-tech/ML-Projects.git)<br>
# ------------------

# %% [markdown]
# ## Extracting the text from txt file

# %%
with open('file.txt','r',encoding='utf-8') as f:
    lines = f.read().strip()
lines = lines.split('\n')
f.close()

# %%
lines
# Out:
# ['Google Analytics is a free web analytics service offered by Google that allows website owners to track and analyse their website traffic. It provides insights into the behaviour of visitors to a website, including how they found the site, how long they stayed, which pages they viewed, and what actions they took. With this information, website owners can make informed decisions about optimising their websites and improving their performance. Businesses, organisations, and individuals widely use Google Analytics to measure the effectiveness of their online marketing campaigns, improve user experience, and increase conversion rates. Google Analytics helps you to track and count visitors, traffic sources, goals, and conversion as it generates reports on Audience Analysis, Acquisition Analysis, Behavior Analysis and Conversion Analysis. ',
#  'Audience analysis gives us an overview of the audience who visit your site, their session history, technology, page views, and bounce rate.',
# ...

# %% [markdown]
# ### Removing Empty strings from the list

# %%
def remove_empty_strings(text):
    new_text = []
    for word in text:
        if word:
            new_text.append(word)

    return new_text


if __name__ == "__main__":
  text = lines
  new_text = remove_empty_strings(text)

  print(new_text)
# Out:
# ['Google Analytics is a free web analytics service offered by Google that allows website owners to track and analyse their website traffic. It provides insights into the behaviour of visitors to a website, including how they found the site, how long they stayed, which pages they viewed, and what actions they took. With this information, website owners can make informed decisions about optimising their websites and improving their performance. Businesses, organisations, and individuals widely use Google Analytics to measure the effectiveness of their online marketing campaigns, improve user experience, and increase conversion rates. Google Analytics helps you to track and count visitors, traffic sources, goals, and conversion as it generates reports on Audience Analysis, Acquisition Analysis, Behavior Analysis and Conversion Analysis. ', 'Audience analysis gives us an overview of the audience who visit your site, their session history, technology, page views, and bounce rate.', 'Acqui
# ...

# %% [markdown]
# ### Tokenizing the words from the list

# %%
def split_text_into_words_from_list(text_list):
  words = []
  for text in text_list:
    words.extend(text.split())
  return words

if __name__ == "__main__":
    words = split_text_into_words_from_list(lines)

  # Remove "Analysis. " whitespace and full stop from the list.
    words = [word for word in words if not word == "Analysis. "]
    words = [word.strip() for word in words]
    words = [word[:-1] if word.endswith(".") else word for word in words]
    words = [word.replace(",", "") for word in words]
    words = [word.replace("'", "") for word in words]
    words = [word.replace(":", "") for word in words]
    print(words)
# Out:
# ['Google', 'Analytics', 'is', 'a', 'free', 'web', 'analytics', 'service', 'offered', 'by', 'Google', 'that', 'allows', 'website', 'owners', 'to', 'track', 'and', 'analyse', 'their', 'website', 'traffic', 'It', 'provides', 'insights', 'into', 'the', 'behaviour', 'of', 'visitors', 'to', 'a', 'website', 'including', 'how', 'they', 'found', 'the', 'site', 'how', 'long', 'they', 'stayed', 'which', 'pages', 'they', 'viewed', 'and', 'what', 'actions', 'they', 'took', 'With', 'this', 'information', 'website', 'owners', 'can', 'make', 'informed', 'decisions', 'about', 'optimising', 'their', 'websites', 'and', 'improving', 'their', 'performance', 'Businesses', 'organisations', 'and', 'individuals', 'widely', 'use', 'Google', 'Analytics', 'to', 'measure', 'the', 'effectiveness', 'of', 'their', 'online', 'marketing', 'campaigns', 'improve', 'user', 'experience', 'and', 'increase', 'conversion', 'rates', 'Google', 'Analytics', 'helps', 'you', 'to', 'track', 'and', 'count', 'visitors', 'traffic', 
# ...

# %% [markdown]
# #### Converting the words to lower case

# %%
text = [word.lower() for word in words]
print(text)
# Out:
# ['google', 'analytics', 'is', 'a', 'free', 'web', 'analytics', 'service', 'offered', 'by', 'google', 'that', 'allows', 'website', 'owners', 'to', 'track', 'and', 'analyse', 'their', 'website', 'traffic', 'it', 'provides', 'insights', 'into', 'the', 'behaviour', 'of', 'visitors', 'to', 'a', 'website', 'including', 'how', 'they', 'found', 'the', 'site', 'how', 'long', 'they', 'stayed', 'which', 'pages', 'they', 'viewed', 'and', 'what', 'actions', 'they', 'took', 'with', 'this', 'information', 'website', 'owners', 'can', 'make', 'informed', 'decisions', 'about', 'optimising', 'their', 'websites', 'and', 'improving', 'their', 'performance', 'businesses', 'organisations', 'and', 'individuals', 'widely', 'use', 'google', 'analytics', 'to', 'measure', 'the', 'effectiveness', 'of', 'their', 'online', 'marketing', 'campaigns', 'improve', 'user', 'experience', 'and', 'increase', 'conversion', 'rates', 'google', 'analytics', 'helps', 'you', 'to', 'track', 'and', 'count', 'visitors', 'traffic', 
# ...

# %% [markdown]
# ### Removing the stop words from the list using self-made list

# %%
def remove_stopwords(text):
    stopwords = ['i','It', 'me','user','by','use','us','The','2', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't","a", "an", "the", "is", "are", "was", "were", "be", "been", "of", "at", "in", "on", "to", "for", "by", "with", "from", "as", "but", "or", "yet", "so", "nor"]
    filtered_list = []
    for word in text:
        if word not in stopwords:
            filtered_list.append(word)
    return filtered_list

filtered_list = remove_stopwords(text)
print(filtered_list)
# Out:
# ['google', 'analytics', 'free', 'web', 'analytics', 'service', 'offered', 'google', 'allows', 'website', 'owners', 'track', 'analyse', 'website', 'traffic', 'provides', 'insights', 'behaviour', 'visitors', 'website', 'including', 'found', 'site', 'long', 'stayed', 'pages', 'viewed', 'actions', 'took', 'information', 'website', 'owners', 'make', 'informed', 'decisions', 'optimising', 'websites', 'improving', 'performance', 'businesses', 'organisations', 'individuals', 'widely', 'google', 'analytics', 'measure', 'effectiveness', 'online', 'marketing', 'campaigns', 'improve', 'experience', 'increase', 'conversion', 'rates', 'google', 'analytics', 'helps', 'track', 'count', 'visitors', 'traffic', 'sources', 'goals', 'conversion', 'generates', 'reports', 'audience', 'analysis', 'acquisition', 'analysis', 'behavior', 'analysis', 'conversion', 'analysis', 'audience', 'analysis', 'gives', 'overview', 'audience', 'visit', 'site', 'session', 'history', 'technology', 'page', 'views', 'bounce', 
# ...

# %% [markdown]
# #### Counting the occurence of words and arranging in decending order

# %%
import pandas as pd

words = filtered_list
words = list(map(str.lower, words))

word_count = {}
for word in words:
    if word not in word_count:
        word_count[word] = 1
    else:
        word_count[word] += 1
sorted_words = sorted(word_count.items(), key=lambda x: x[1], reverse=True)
df = pd.DataFrame(sorted_words, columns=['Word', 'Count'])
for word, count in sorted_words:
    print(f'{word}: {count}')
# Out:
# data: 47
# google: 24
# databases: 24
# analytics: 23
# relational: 11
# document-based: 11
# web: 9
# performance: 9
# storing: 9
# large: 9
# nosql: 9
# analysis: 8
# website: 7
# handle: 7
# volumes: 7
# traffic: 6
# database: 6
# processing: 6
# site: 5
# websites: 5
# application: 5
# highly: 5
# cost-effective: 5
# designed: 5
# scalability: 5
# sharding: 5
# conversion: 4
# amounts: 4
# real-time: 4
# may: 4
# generated: 4
# scalable: 4
# traditional: 4
# multiple: 4
# schema: 4
# especially: 4
# replication: 4
# allows: 3
# insights: 3
# sources: 3
# generates: 3
# audience: 3
# acquisition: 3
# like: 3
# suitable: 3
# needs: 3
# massive: 3
# querying: 3
# making: 3
# expensive: 3
# horizontally: 3
# means: 3
# flexibility: 3
# meaning: 3
# easy: 3
# unstructured: 3
# even: 3
# hardware: 3
# scale: 3
# flexible: 3
# capabilities: 3
# high: 3
# different: 3
# shard: 3
# stored: 3
# owners: 2
# track: 2
# provides: 2
# behaviour: 2
# visitors: 2
# including: 2
# make: 2
# ...

# %%
df_viz = df[:26]
df_viz
# Out:
#               Word  Count
# 0             data     47
# 1           google     24
# 2        databases     24
# 3        analytics     23
# 4       relational     11
# 5   document-based     11
# 6              web      9
# 7      performance      9
# 8          storing      9
# 9            large      9
# 10           nosql      9
# 11        analysis      8
# 12         website      7
# 13          handle      7
# 14         volumes      7
# 15         traffic      6
# 16        database      6
# 17      processing      6
# 18            site      5
# 19        websites      5
# 20     application      5
# 21          highly      5
# 22  cost-effective      5
# 23        designed      5
# 24     scalability      5
# 25        sharding      5

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.barplot(x= df_viz.Count, y= df_viz.Word)
plt.show()

# %% [markdown]
# ## INFERENCE

# %% [markdown]
# * The word 'data' is being reapeated the most number of times in the study of Google Analytics Report.
